# %%
import pandas as pd
import numpy as np

df = pd.read_excel("C:/Users/admin/Downloads/jet_speed_real.xlsx", header=8)
df.head()
# Out:
#           PROJECT_NAME                  TIMESTAMP  PM2.5   PM10  TEMPERATURE  \
# 0  Jet Speed Real Tors  2025-12-01T00:00:24+05:30   85.0  141.0         24.6
# 1  Jet Speed Real Tors  2025-12-01T00:00:54+05:30   84.0  145.0         24.6
# 2  Jet Speed Real Tors  2025-12-01T00:01:24+05:30   85.0  145.0         24.5
# 3  Jet Speed Real Tors  2025-12-01T00:01:54+05:30   80.0  141.0         24.5
# 4  Jet Speed Real Tors  2025-12-01T00:02:24+05:30   88.0  143.0         24.6
#
#    HUMIDITY
# 0      61.6
# 1      61.4
# 2      61.3
# 3      61.8
# 4      62.4

# %%
#Converting from timestamp to datetime
df['TIMESTAMP'] = pd.to_datetime(df['TIMESTAMP'], format='mixed')

# %%
#Set Index
df = df.set_index('TIMESTAMP')

# %%
#Resample data into 1hour batch
sensor_df = df.resample('1h').mean(numeric_only=True)

# %%
#Checking  Type of Index
print(type(df.index))
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
#Interpolate: to replace with mode value of any  columns
sensor_df = sensor_df.interpolate(limit_direction='forward')

# %%
#Round-Of Data
sensor_df[['PM2.5','PM10','TEMPERATURE','HUMIDITY']] = sensor_df[['PM2.5','PM10','TEMPERATURE','HUMIDITY']].round(2)

# %%
#Reset Index
sensor_df = sensor_df.reset_index()

# %%
sensor_df.head(20)
# Out:
#                    TIMESTAMP  PM2.5    PM10  TEMPERATURE  HUMIDITY
# 0  2025-12-01 00:00:00+05:30  92.21  156.42        24.35     63.19
# 1  2025-12-01 01:00:00+05:30  96.36  164.24        24.24     62.70
# 2  2025-12-01 02:00:00+05:30  82.24  141.06        23.95     61.23
# 3  2025-12-01 03:00:00+05:30  75.14  129.88        23.50     61.03
# 4  2025-12-01 04:00:00+05:30  79.18  135.31        23.42     59.54
# 5  2025-12-01 05:00:00+05:30  95.70  163.18        23.28     57.88
# 6  2025-12-01 06:00:00+05:30  97.09  167.39        22.98     59.05
# 7  2025-12-01 07:00:00+05:30  97.49  167.94        23.23     60.03
# 8  2025-12-01 08:00:00+05:30  84.18  143.77        26.76     49.78
# 9  2025-12-01 09:00:00+05:30  77.49  131.24        30.77     40.82
# 10 2025-12-01 10:00:00+05:30  72.43  121.39        34.82     33.27
# 11 2025-12-01 11:00:00+05:30  76.08  125.03        36.92     30.61
# 12 2025-12-01 12:00:00+05:30  66.02  106.72        40.88     22.77
# 13 2025-12-01 13:00:00+05:30  62.59  101.09        42.95     21.93
# 14 2025-12-01 14:00:00+05:30  59.99   97.66        41.23     29.49
# 15 2025-12-01 15:00:00+05:30  58.86   96.95        34.32     39.85
# 16 2025-12-01 16:00:00+05:30  56.29   94.14        31.25     43.59
# 17 2025-12-01 17:00:00+05:30  59.76  101.90        29.14     51.45
# 18 2025-12-01 18:00:00+05:30  66.88  115.91        27.14     60.52
# 19 2025-12-01 19:00:00+05:30  74.93  129.18        26.11     64.24

# %% [markdown]
# Weather Data

# %%
#Weather Data 
weather_df = pd.read_excel("C:/Users/admin/Downloads/kherbadi_bandra.xlsx", header=16)
weather_df
# Out:
#              From Date           To Date  Ozone     RH    WS      WD      SR  \
# 0     01-12-2025 00:00  01-12-2025 01:00   1.20  60.63  0.96  145.86    0.00
# 1     01-12-2025 01:00  01-12-2025 02:00   1.85  56.44  1.01   98.04    0.00
# 2     01-12-2025 02:00  01-12-2025 03:00   2.23  57.06  0.84  104.93    0.00
# 3     01-12-2025 03:00  01-12-2025 04:00   2.25  56.80  0.72   85.60    0.00
# 4     01-12-2025 04:00  01-12-2025 05:00   0.93  56.16  0.57  138.53    0.00
# ...                ...               ...    ...    ...   ...     ...     ...
# 2744  25-03-2026 08:00  25-03-2026 09:00   2.08  60.69  0.24  224.96  259.07
# 2745  25-03-2026 09:00  25-03-2026 10:00  11.70  51.67  0.66  289.12  451.88
# 2746  25-03-2026 10:00  25-03-2026 11:00  20.35  53.74  1.17  275.96  613.07
# 2747  25-03-2026 11:00  25-03-2026 12:00  25.45  57.96  1.34  279.95  682.40
# 2748  25-03-2026 12:00  25-03-2026 12:04    NaN    NaN   NaN     NaN     NaN
#
#        RF     AT
# 0     0.0  23.32
# 1     0.0  23.97
# 2     0.0  23.27
# 3     0.0  22.61
# 4     0.0  22.31
# ...   ...    ...
# 2744  0.0  30.91
# 2745  0.0  32.85
# 2746  0.0  33.78
# 2747  0.0  33.76
# 2748  NaN    NaN
#
# [2749 rows x 9 columns]

# %%
#Remode To Date Columns
weather_df = weather_df.drop('To Date',axis=1)

# %%
weather_df.set_index('From Date')
# Out:
#                   Ozone     RH    WS      WD      SR   RF     AT
# From Date
# 01-12-2025 00:00   1.20  60.63  0.96  145.86    0.00  0.0  23.32
# 01-12-2025 01:00   1.85  56.44  1.01   98.04    0.00  0.0  23.97
# 01-12-2025 02:00   2.23  57.06  0.84  104.93    0.00  0.0  23.27
# 01-12-2025 03:00   2.25  56.80  0.72   85.60    0.00  0.0  22.61
# 01-12-2025 04:00   0.93  56.16  0.57  138.53    0.00  0.0  22.31
# ...                 ...    ...   ...     ...     ...  ...    ...
# 25-03-2026 08:00   2.08  60.69  0.24  224.96  259.07  0.0  30.91
# 25-03-2026 09:00  11.70  51.67  0.66  289.12  451.88  0.0  32.85
# 25-03-2026 10:00  20.35  53.74  1.17  275.96  613.07  0.0  33.78
# 25-03-2026 11:00  25.45  57.96  1.34  279.95  682.40  0.0  33.76
# 25-03-2026 12:00    NaN    NaN   NaN     NaN     NaN  NaN    NaN
#
# [2749 rows x 7 columns]

# %%
#Replace From Date to TIMESTAMP
weather_df.rename(columns={'From Date':'TIMESTAMP'}, inplace=True)

# %%
weather_df = weather_df.set_index('TIMESTAMP')

# %%
#Making Timestamp same
sensor_df['TIMESTAMP'] = sensor_df['TIMESTAMP'].dt.tz_localize(None)
#print(sensor_df.columns)
#sensor_df.head()

# %%
print(weather_df.columns)
# Out:
# Index(['Ozone', 'RH', 'WS', 'WD', 'SR', 'RF', 'AT'], dtype='object')

# %%
weather_df.tail()
# Out:
#                   Ozone     RH    WS      WD      SR   RF     AT
# TIMESTAMP
# 25-03-2026 08:00   2.08  60.69  0.24  224.96  259.07  0.0  30.91
# 25-03-2026 09:00  11.70  51.67  0.66  289.12  451.88  0.0  32.85
# 25-03-2026 10:00  20.35  53.74  1.17  275.96  613.07  0.0  33.78
# 25-03-2026 11:00  25.45  57.96  1.34  279.95  682.40  0.0  33.76
# 25-03-2026 12:00    NaN    NaN   NaN     NaN     NaN  NaN    NaN

# %%
weather_df = weather_df.reset_index()

# %%
weather_df['TIMESTAMP'] = pd.to_datetime(
    weather_df['TIMESTAMP'],
    format='%d-%m-%Y %H:%M'
)

# %%
weather_df.head()
# Out:
#             TIMESTAMP  Ozone     RH    WS      WD   SR   RF     AT
# 0 2025-12-01 00:00:00   1.20  60.63  0.96  145.86  0.0  0.0  23.32
# 1 2025-12-01 01:00:00   1.85  56.44  1.01   98.04  0.0  0.0  23.97
# 2 2025-12-01 02:00:00   2.23  57.06  0.84  104.93  0.0  0.0  23.27
# 3 2025-12-01 03:00:00   2.25  56.80  0.72   85.60  0.0  0.0  22.61
# 4 2025-12-01 04:00:00   0.93  56.16  0.57  138.53  0.0  0.0  22.31

# %%
#weather_df = weather_df.drop('Ozone',axis=1)

# %%
weather_df.head()
# Out:
#             TIMESTAMP  Ozone     RH    WS      WD   SR   RF     AT
# 0 2025-12-01 00:00:00   1.20  60.63  0.96  145.86  0.0  0.0  23.32
# 1 2025-12-01 01:00:00   1.85  56.44  1.01   98.04  0.0  0.0  23.97
# 2 2025-12-01 02:00:00   2.23  57.06  0.84  104.93  0.0  0.0  23.27
# 3 2025-12-01 03:00:00   2.25  56.80  0.72   85.60  0.0  0.0  22.61
# 4 2025-12-01 04:00:00   0.93  56.16  0.57  138.53  0.0  0.0  22.31

# %%
#Merge Data So our ML model can train
merged_df = pd.merge(sensor_df,weather_df, on="TIMESTAMP")

# %%
merged_df = merged_df.dropna()

# %%
merged_df.size
# Out:
# 31032

# %% [markdown]
# LSTM PREDICTION MODEL (72 HOURS PAST DATA - 24 HOURS FUTURE PREDICTION)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, accuracy_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
#Select Features
features = [
    'PM2.5', 'PM10', 'TEMPERATURE', 'HUMIDITY',
    'WS', 'WD', 'RF', 'Ozone'
]

data = merged_df[features]

# %%
#Normalize Data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

# %%
#Create Sequence
def create_sequences(data, window=72, horizon=24):
    X, y = [], []
    
    for i in range(len(data) - window - horizon):
        X.append(data[i:i+window])
        y.append(data[i+window:i+window+horizon, 0:2])  # PM2.5, PM10
    
    return np.array(X), np.array(y)

X, y = create_sequences(scaled_data)

# %%
#Train-Test Split
split = int(len(X) * 0.8)

X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
#Build LSTM Model
from tensorflow.keras.layers import Input

model = Sequential([
    Input(shape=(72, X.shape[2])),

    LSTM(128, return_sequences=True),
    Dropout(0.2),

    LSTM(64),
    Dropout(0.2),

    Dense(32, activation='relu'),
    Dense(48)
])

# %%
#Compile Model
model.compile(
    optimizer='adam',
    loss='mse'
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
#Train Model
model.fit(
    X_train,
    y_train.reshape(y_train.shape[0], -1),
    epochs=20,
    batch_size=32,
    validation_data=(X_test, y_test.reshape(y_test.shape[0], -1))
)
# Out:
# Epoch 1/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 18s 123ms/step - loss: 0.0017 - val_loss: 0.0351
# Epoch 2/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 9.5837e-04 - val_loss: 0.0274
# Epoch 3/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 5.1613e-04 - val_loss: 0.0264
# Epoch 4/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 4.5707e-04 - val_loss: 0.0258
# Epoch 5/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 129ms/step - loss: 3.9713e-04 - val_loss: 0.0259
# Epoch 6/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - loss: 3.5072e-04 - val_loss: 0.0262
# Epoch 7/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 3.3713e-04 - val_loss: 0.0263
# Epoch 8/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 3.3825e-04 - val_loss: 0.0267
# Epoch 9/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - loss: 3.3557e-04 - val_loss: 0.0269
# Epoch 10/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 72ms/step - loss: 3.2159e-04 - val_loss: 0.0263
# Epoch 11/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 101ms/step - loss: 3.1411e-04 - val_loss: 0.0266
# Epoch 12/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 3.0455e-04 - val_loss: 0.0267
# Epoch 13/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 114ms/step - loss: 2.8785e-04 - val_loss: 0.0264
# Epoch 14/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - loss: 2.9431e-04 - val_loss: 0.0271
# Epoch 15/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 106ms/step - loss: 2.8582e-04 - val_loss: 0.0273
# Epoch 16/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 99ms/step - loss: 2.7261e-04 - val_loss: 0.0265
# Epoch 17/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - loss: 2.5664e-04 - val_loss: 0.0269
# Epoch 18/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 112ms/step - loss: 2.5165e-04 - val_loss: 0.0263
# Epoch 19/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 141ms/step - loss: 2.4510e-04 - val_loss: 0.0267
# Epoch 20/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 116ms/step - loss: 2.4258e-04 - val_loss: 0.0265

# %%
#Predict
pred = model.predict(X_test)

# reshape back to (samples, 24, 2)
pred = pred.reshape(-1, 24, 2)
y_test = y_test.reshape(-1, 24, 2)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step

# %%
#Evaluate
mae_pm25 = mean_absolute_error(y_test[:,:,0].flatten(), pred[:,:,0].flatten())
mae_pm10 = mean_absolute_error(y_test[:,:,1].flatten(), pred[:,:,1].flatten())

print("PM2.5 MAE:", mae_pm25)
print("PM10 MAE:", mae_pm10)
# Out:
# PM2.5 MAE: 0.04870748858572608
# PM10 MAE: 0.04972649895476893

# %%
#Convert to Work/Not
PM25_LIMIT = 100
PM10_LIMIT = 250

def decision(pm25, pm10):
    return 0 if (pm25 > PM25_LIMIT or pm10 > PM10_LIMIT) else 1

# %%
#Decision Accuracy
actual = []
predicted = []

for i in range(len(pred)):
    for t in range(24):
        actual.append(decision(y_test[i, t, 0], y_test[i, t, 1]))
        predicted.append(decision(pred[i, t, 0], pred[i, t, 1]))

from sklearn.metrics import accuracy_score, classification_report

print("Decision Accuracy:", accuracy_score(actual, predicted))
print(classification_report(actual, predicted))
# Out:
# Decision Accuracy: 1.0
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     11952
#
#     accuracy                           1.00     11952
#    macro avg       1.00      1.00      1.00     11952
# weighted avg       1.00      1.00      1.00     11952

# %%
#Real-Time Prediction
# Take last 72 hours
last_72 = scaled_data[-72:]

# reshape for model
last_72 = last_72.reshape(1, 72, X.shape[2])

future = model.predict(last_72)

future = future.reshape(24, 2)

# Example: next day average PM
pm25_next = future[:,0].mean()
pm10_next = future[:,1].mean()

print("Tomorrow Avg PM2.5:", pm25_next)
print("Tomorrow Avg PM10:", pm10_next)

if decision(pm25_next, pm10_next):
    print("✅ CONTINUE WORK")
else:
    print("❌ STOP WORK")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Tomorrow Avg PM2.5: 0.0037938363
# Tomorrow Avg PM10: 0.0058282637
# ✅ CONTINUE WORK

# %%
# Save full model
model.save("lstm_model3.h5")

# Save scaler (VERY IMPORTANT)
import joblib
joblib.dump(scaler, "scaler3.pkl")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ['scaler3.pkl']

# %%
merged_df.to_csv("merged_df3.csv", index=False)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\admin\Site_Work_Prediction_ML_Model

# %%
print(os.listdir())
# Out:
# ['.git', '.ipynb_checkpoints', '24March Data Resample.ipynb', 'app.py', 'Future Prediction Model.ipynb', 'lstm_model.h5', 'lstm_model2.h5', 'lstm_model3.h5', 'merged_df.csv', 'merged_df2.csv', 'merged_df3.csv', 'Predicting site with anomalies data.ipynb', 'Predicting with Jalaram Developers Data.ipynb', 'README.md', 'requirements.txt', 'scaler.pkl', 'scaler2.pkl', 'scaler3.pkl']
